# %%
import gmaps

# %%
# Import the dependencies.
import pandas as pd
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0         Shimoda      JP  2022-08-03 20:28:07  34.6667  138.9500
# 1        1  Severo-Kurilsk      RU  2022-08-03 20:23:59  50.6789  156.1250
# 2        2       Jamestown      US  2022-08-03 20:23:17  42.0970  -79.2353
# 3        3    Puerto Montt      CL  2022-08-03 20:27:37 -41.4698  -72.9447
# 4        4     Port Alfred      ZA  2022-08-03 20:28:07 -33.5906   26.8910
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     77.11        89          61       10.18
# 1     52.84        86          43        7.38
# 2     89.94        39           1        8.99
# 3     45.43       100         100        9.22
# 4     62.19        80          51        1.99

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country                 Date      Lat       Lng  \
# 0         0       Shimoda      JP  2022-08-03 20:28:07  34.6667  138.9500
# 2         2     Jamestown      US  2022-08-03 20:23:17  42.0970  -79.2353
# 9         9       Kavieng      PG  2022-08-03 20:28:09  -2.5744  150.7967
# 18       18        Atuona      PF  2022-08-03 20:28:12  -9.8000 -139.0333
# 21       21      Ajdabiya      LY  2022-08-03 20:28:12  30.7554   20.2263
# 22       22  Komsomolskiy      UZ  2022-08-03 20:28:13  40.4272   71.7189
# 33       33    Le Vauclin      MQ  2022-08-03 20:28:16  14.5452  -60.8388
# 34       34       Liuzhou      CN  2022-08-03 20:28:16  24.3126  109.3892
# 37       37       Tautira      PF  2022-08-03 20:28:17 -17.7333 -149.1500
# 38       38        Maceio      BR  2022-08-03 20:28:17  -9.6658  -35.7353
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      77.11        89          61       10.18
# 2      89.94        39           1        8.99
# 9      81.86        80          96       17.22
# 18     77.27        77          16       13.82
# 21     86.22        37           0       20.45
# 22     76.14        39           2        0.60
# 33     84.25        79          75       14.97
# 34     79.97        83         100        1.45
# 37     76.73        81          58       24.32
# 38     76.44        88         100        9.22

# %%
preferred_cities_df.count()
# Out:
# City_ID       193
# City          193
# Country       193
# Date          193
# Lat           193
# Lng           193
# Max Temp      193
# Humidity      193
# Cloudiness    193
# Wind Speed    193
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 0        Shimoda      JP     77.11  34.6667  138.9500
# 2      Jamestown      US     89.94  42.0970  -79.2353
# 9        Kavieng      PG     81.86  -2.5744  150.7967
# 18        Atuona      PF     77.27  -9.8000 -139.0333
# 21      Ajdabiya      LY     86.22  30.7554   20.2263
# 22  Komsomolskiy      UZ     76.14  40.4272   71.7189
# 33    Le Vauclin      MQ     84.25  14.5452  -60.8388
# 34       Liuzhou      CN     79.97  24.3126  109.3892
# 37       Tautira      PF     76.73 -17.7333 -149.1500
# 38        Maceio      BR     76.44  -9.6658  -35.7353

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key




}

# %%
# Iterate through the DataFrame.
import pprint
for index, row in hotel_df.iterrows():
        
        
        lat = row["Lat"]
        lng = row["Lng"]

        # Add the latitude and longitude to location key for the params dictionary.
        params["location"] = f"{lat},{lng}"

        # Use the search term: "lodging" and our latitude and longitude.
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        # Make request and get the JSON data from the search.
        hotels = requests.get(base_url, params=params).json()
        pprint.pprint(hotels)
        break
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AeJbb3d5B8LABBi8oIvKnsWg132Gn5pf23kYJycgg1PVlHzQ3miPEzwp2HvoNtmGh03Vn0L-SvI898LwJv2F7D1xoEyMdFIpTvBFpk-jgeq7IuZjfpAVIuQC9FIVGgv1FpIMZXwRIXtMGsrqy4GhwwpBoq-FGxhFJJK5eYdRj55RD2olwUxryc-q6KBTOeD7HQJYFZNezO-CR8HZG2DfulMFmxP6Moi2hLtX4f-bG2CeHPzHwTCav5SNypUv67N4fZ8SBsIdOg9NSyFdokSKlt6iX7JW3bK0VvsVO8OV3jEiTpE4TiYwMAHrZEdchn_y8uuhWF7-2pl1rDJKRbm48UDiRNRT6UJPHwP4T1T10atQOCQCuREA6b5BmBCgFzzP3HY77RyZU_PAZyWlrdUTXgeuUfgwuF4xjjonQ5K4c0gfCFq-72CmIizS_m-m',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.66802209999999,
#                                         'lng': 138.9383239},
#                            'viewport': {'northeast': {'lat': 34.6693644802915,
#                                                       'lng': 138.9396021802915},
#                                         'southwest': {'lat': 34.66666651970851,
#                                                       'lng': 138.9369042197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Shimoda Tokyu Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 720,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110886498659486541853">下田東急ホテル</a>'],
#                           'photo_reference': 'AeJbb3dIj3VHSemCAsL_zS9yuoS2hAHzEsgMlcVL-XlWviD3HPiJPJyrqWNFDmgpa67kllK6nWxMfifeO_QrjmAdSckTDffjSJoUZbg4z3WQLG7vjC315Pfix1XF0AFnetun1i5ee3vAGPR7IRzjsG3mBu98Ty4CwAGPw0SlAobGgH8aC28h',
#                           'width': 1080}],
#               'place_id': 'ChIJGS8nUepYF2ARTPQTX2wS96A',
#               'plus_code': {'compound_code': 'MW9Q+68 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMW9Q+68'},
#               'rating': 4.2,
#               'reference': 'ChIJGS8nUepYF2ARTPQTX2wS96A',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 857,
#               'vicinity': '5-12-1, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6870091, 'lng': 138.9712892},
#                            'viewport': {'northeast': {'lat': 34.6883320302915,
#                                                       'lng': 138.9724783802915},
#                                         'southwest': {'lat': 34.68563406970851,
#                                                       'lng': 138.9697804197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Izukyu',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113333349070944282560">Ram</a>'],
#                           'photo_reference': 'AeJbb3cw0Aj6I-dLMkYHgTNFinkVpEXHi2iyfbMkwJadElfKAxY6O8YwrJlqtKddo2vN7b4Py4_W9FFxA0d9bCM9dWmLAiFNC21kfYnfU2U8v_slPCYL4I3hoDFFVK-VcYA9WsUnVimX-D3lZD6f1uFqJvsnjhqJ3XveigHF17360AwKvP0M',
#                           'width': 4032}],
#               'place_id': 'ChIJhVMCMEZfF2AR7Sqhomn5YB4',
#               'plus_code': {'compound_code': 'MXPC+RG Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXPC+RG'},
#               'rating': 4,
#               'reference': 'ChIJhVMCMEZfF2AR7Sqhomn5YB4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1006,
#               'vicinity': '2732-7 Shirahama, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6617739, 'lng': 138.9337707},
#                            'viewport': {'northeast': {'lat': 34.6628670802915,
#                                                       'lng': 138.9350662802915},
#                                         'southwest': {'lat': 34.6601691197085,
#                                                       'lng': 138.9323683197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Shimoda Yamatokan',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1280,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108699537512210066554">NORIAKI '
#                                                 'SAKATA</a>'],
#                           'photo_reference': 'AeJbb3dZw9LvKtoyoewIUqzSdVJ99WVN-kCiwKWsjTGoPPs2AtlUdezHWH2aPwtYFeKGZlTKt7i8MWdQpweey4zZTmHiSIxqO1kaXxFQBNVJcT27QaGebz4MqyB9rt7g1KlcxC3cl-u0pSZGwrL3Eks5JQp-ty3ZXvvjq1k9adAz1LSSQqwn',
#                           'width': 2560}],
#               'place_id': 'ChIJ0f8oHO9YF2ARLzLU6gmIfQQ',
#               'plus_code': {'compound_code': 'MW6M+PG Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMW6M+PG'},
#               'rating': 4.2,
#               'reference': 'ChIJ0f8oHO9YF2ARLzLU6gmIfQQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 753,
#               'vicinity': '2048 Kisami, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6757085, 'lng': 138.9526423},
#                            'viewport': {'northeast': {'lat': 34.6768876302915,
#                                                       'lng': 138.9544185302915},
#                                         'southwest': {'lat': 34.6741896697085,
#                                                       'lng': 138.9517205697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Kurofune Hotel',
#               'photos': [{'height': 1333,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106987752408014744791">黒船ホテル</a>'],
#                           'photo_reference': 'AeJbb3fLRXgG5LL0QkgpZvSjq2hn_So5VHFv7T_7428ajKWT8xWwFZv527qF8_l3A22MqF8ncIyslGgMmL49vMgAHvPxfJ6s-B98eFyZylj6PWXXU_06neQ9uvCL_4IcqN51Uxamzf_PphdJawiUIhBZlJe4SkbFjROqwZSt1NRInrRktcJS',
#                           'width': 2000}],
#               'place_id': 'ChIJIdAtN8hYF2ARXI_9zYTkfuM',
#               'plus_code': {'compound_code': 'MXG3+73 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXG3+73'},
#               'rating': 3.8,
#               'reference': 'ChIJIdAtN8hYF2ARXI_9zYTkfuM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 644,
#               'vicinity': '3-8 Kakisaki, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.658732, 'lng': 138.925775},
#                            'viewport': {'northeast': {'lat': 34.6600273802915,
#                                                       'lng': 138.9272125802915},
#                                         'southwest': {'lat': 34.6573294197085,
#                                                       'lng': 138.9245146197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Toutei The Japanese-style',
#               'photos': [{'height': 801,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118239337298497941619">順太</a>'],
#                           'photo_reference': 'AeJbb3ebW4KmNWP8OfWSggv4vAFSnM6_N2CebPMxpDbIs20QorkE-DDP4RV7wYykZbjxlSc6uWp4lkjF-5ncHgw3wQ0FFcduAuci8cRKswZDDs91Jcx6Q_M0BtplAnCg3LXJSi4X3d5n9AwpExvt4Hq6jw1J-M4q9GjaRSqBm6KJtumC3dn0',
#                           'width': 1200}],
#               'place_id': 'ChIJl3KiKfFYF2ARTqWvzpM85Cg',
#               'plus_code': {'compound_code': 'MW5G+F8 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMW5G+F8'},
#               'rating': 4.3,
#               'reference': 'ChIJl3KiKfFYF2ARTqWvzpM85Cg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 168,
#               'vicinity': '348-7 Kisami, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6768947, 'lng': 138.9282688},
#                            'viewport': {'northeast': {'lat': 34.6782850802915,
#                                                       'lng': 138.9296793302915},
#                                         'southwest': {'lat': 34.6755871197085,
#                                                       'lng': 138.9269813697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'マックミルハウス 下田',
#               'photos': [{'height': 2160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112030100152186778640">Akihiro '
#                                                 'Channel</a>'],
#                           'photo_reference': 'AeJbb3e6a48IPUBjLSO4AdxdS8Sb81_QTGn2VjdAHL4ThOmjJ50macn9S9LOlyg3Uiv6DH4vI0AkDNw4sJr0YyxWAtYojQMGSftkal1U8R4qYmxg_MHUNphVCFv5D7CoHCq-qQoRp4_jSVK1AnGr_cTCitu7nwyUwN55um--4V0CDbtfmfnR',
#                           'width': 3840}],
#               'place_id': 'ChIJFSO5MJJYF2AR_d07KdPoVWE',
#               'plus_code': {'compound_code': 'MWGH+Q8 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMWGH+Q8'},
#               'rating': 3.7,
#               'reference': 'ChIJFSO5MJJYF2AR_d07KdPoVWE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 15,
#               'vicinity': '720-12 Rokuchōme, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.696196, 'lng': 138.973281},
#                            'viewport': {'northeast': {'lat': 34.69759543029151,
#                                                       'lng': 138.9744296302915},
#                                         'southwest': {'lat': 34.69489746970851,
#                                                       'lng': 138.9717316697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Shimoda Prince Hotel',
#               'photos': [{'height': 1499,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113710098177282656091">下田プリンスホテル</a>'],
#                           'photo_reference': 'AeJbb3fPPgoetSve3XD4zvy08aB5h0abNukUgDlLtVNQgIgxBZIhrRR0oQJovkOKI0FNedFTYsSTX4TgvqFECRA0bennTkM6fUhE-KuFZMHAMtDc7xpNyQotIxjM3HRf8mtoRXi-BMTLkdlIta3bwTrNosl_XDCnf5SKuHqDtMU-slldtCnm',
#                           'width': 2000}],
#               'place_id': 'ChIJ89KUAVtfF2ARVbPPuwt_TVc',
#               'plus_code': {'compound_code': 'MXWF+F8 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXWF+F8'},
#               'rating': 3.9,
#               'reference': 'ChIJ89KUAVtfF2ARVbPPuwt_TVc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 815,
#               'vicinity': '1547-1 Shirahama, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6929131, 'lng': 138.9718112},
#                            'viewport': {'northeast': {'lat': 34.6943086302915,
#                                                       'lng': 138.9731225302915},
#                                         'southwest': {'lat': 34.69161066970851,
#                                                       'lng': 138.9704245697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Beachside Inn Shirahama',
#               'photos': [{'height': 825,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105614194945374660942">ビーチサイドイン白浜</a>'],
#                           'photo_reference': 'AeJbb3c1BewKAWFgmpuFj37oxgmpvAilQRrISMU1dVAF9EyIoxXzjJik1WDUHNJKygbgzXLo0V5lIxGmsIntqhJPe9APN8EW_ekREQLtiNoAsMbxrvh7eSP45GzKppzaEvvxSEuOVUzczxMi4BOyFaO1knqCBCAcsfoEUT8BAV17MmH6RwzV',
#                           'width': 1238}],
#               'place_id': 'ChIJBTHaR0VfF2ARlEOXaJ0Hqwo',
#               'plus_code': {'compound_code': 'MXVC+5P Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXVC+5P'},
#               'rating': 4.5,
#               'reference': 'ChIJBTHaR0VfF2ARlEOXaJ0Hqwo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 53,
#               'vicinity': '1742 Shirahama, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.65538540000001,
#                                         'lng': 138.9210344},
#                            'viewport': {'northeast': {'lat': 34.65669073029149,
#                                                       'lng': 138.9223904802915},
#                                         'southwest': {'lat': 34.65399276970849,
#                                                       'lng': 138.9196925197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'BY THE SEA',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112451715860582939630">海老名秋子</a>'],
#                           'photo_reference': 'AeJbb3f4mES6r_3XY58cyqozuIkXz4-HIh1gWixMPig5fFzNebu4OlsurNmIj3jaDrR3RL1rFewZh6QO4wKvCOc8x6wwnbmz4_hz_sweqSNvncLQc3rXpX803L_7ndFZKdh_0QkYJzR3Kh-9t0jeiUT4SnSDs0qs0PM3X1dl2Rcsz3iyIiDV',
#                           'width': 4032}],
#               'place_id': 'ChIJEyQd6fdYF2ARvcb_9dUfkbQ',
#               'plus_code': {'compound_code': 'MW4C+5C Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMW4C+5C'},
#               'rating': 3.1,
#               'reference': 'ChIJEyQd6fdYF2ARvcb_9dUfkbQ',
#               'scope': 'GOOGLE',
#               'types': ['airport',
#                         'lodging',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 53,
#               'vicinity': '2248-2 Kisami, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6773677, 'lng': 138.9719223},
#                            'viewport': {'northeast': {'lat': 34.6788674802915,
#                                                       'lng': 138.9732127302915},
#                                         'southwest': {'lat': 34.6761695197085,
#                                                       'lng': 138.9705147697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Shimoda View Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 480,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115853817117231397075">下田ビューホテル</a>'],
#                           'photo_reference': 'AeJbb3f6B8Xuz43RZruboq2iIt3UEHsr1kt34H4z43wydigV85NUtxGSBXte_AuE1UJg_zv1ZG0VD0ns6xDk9X94k6Fs2BBGrQlg8kNdVhVr3YFZJ4hV6EDuQXR7P0aXD8YJ-_v4ixu75Jjzus1dK3_boSFKQITxVQiWytbFHHgDt-cPx7zZ',
#                           'width': 640}],
#               'place_id': 'ChIJVwPKijpfF2ARNJMLqYQ4F_E',
#               'plus_code': {'compound_code': 'MXGC+WQ Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXGC+WQ'},
#               'rating': 3.9,
#               'reference': 'ChIJVwPKijpfF2ARNJMLqYQ4F_E',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 481,
#               'vicinity': '633 Kakisaki, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6832594, 'lng': 138.9763461},
#                            'viewport': {'northeast': {'lat': 34.6845773302915,
#                                                       'lng': 138.9776764302915},
#                                         'southwest': {'lat': 34.6818793697085,
#                                                       'lng': 138.9749784697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Gardenvilla Shirahama',
#               'photos': [{'height': 6144,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103351355983226359895">Ashly</a>'],
#                           'photo_reference': 'AeJbb3eLEmEKjs5EEfXJhVijeRNQIXX5XrmKxhnUsoorlURp_yzcR0JULKwP5mqMjLsWQsvvZtzzDjPa1SYTzi_shXMz4Q856gEF2BaZ1OPcGsUzrxDnUqtlwHOu-UdbG0D8SCrRc-9KK36BoKKy0ALVn9NkK5jlRMyNwrSpdDP1CPUUpLDh',
#                           'width': 10944}],
#               'place_id': 'ChIJ_4qixT5fF2ARUNKFIQg6rbk',
#               'plus_code': {'compound_code': 'MXMG+8G Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXMG+8G'},
#               'rating': 4.5,
#               'reference': 'ChIJ_4qixT5fF2ARUNKFIQg6rbk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 141,
#               'vicinity': '2644-1 Shirahama, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.649021, 'lng': 138.9112004},
#                            'viewport': {'northeast': {'lat': 34.6505097302915,
#                                                       'lng': 138.9125324302915},
#                                         'southwest': {'lat': 34.6478117697085,
#                                                       'lng': 138.9098344697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Livemax Resort Izu Shimoda',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2736,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108692298976175668225">Image '
#                                                 'Creation Studio</a>'],
#                           'photo_reference': 'AeJbb3fyzfnBMlS9TQbIGWUOG8Kho6VH1IzOu-Ja2f3ICdBl-X7XnN0RjBiDKQxjIc5s7CNBYVhnJWm022OnDCSy2RfISrPutdmfSY2BWrqBvzqmqkQW4MUq63JZyGY7jc7TBpnbhCxq8djFOUqeyTMMv690k00i7zWLzDbMxiSy4lBhOkXD',
#                           'width': 4864}],
#               'place_id': 'ChIJc_MiOVBYF2AR4sknVV5j1Tg',
#               'plus_code': {'compound_code': 'JWX6+JF Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WJWX6+JF'},
#               'rating': 3.7,
#               'reference': 'ChIJc_MiOVBYF2AR4sknVV5j1Tg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 332,
#               'vicinity': '711-3 Touji, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6772534, 'lng': 138.9719014},
#                            'viewport': {'northeast': {'lat': 34.67880853029151,
#                                                       'lng': 138.9732243802915},
#                                         'southwest': {'lat': 34.67611056970851,
#                                                       'lng': 138.9705264197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'シャンタン',
#               'photos': [{'height': 2160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117621443106088966105">はむのはむす</a>'],
#                           'photo_reference': 'AeJbb3dNm0IAxHbMk4H-sopTBKgpKYGrZ8xrENNWvSUG8iEfbpOmVCN6xCXb1WgTVnYxq_lvU5lg6y1yAM9tB5Auxnh8bBY8FAjFRx25KSa5GqYVP6eD8LARpKXEJ_o2rrZDLsBe4Bxbr1UxudErp7Y3Ir57Ff2PsFFq8ovi70ayImuKQFoZ',
#                           'width': 3840}],
#               'place_id': 'ChIJVwPKijpfF2ARsxHtEFgRksQ',
#               'plus_code': {'compound_code': 'MXGC+WQ Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXGC+WQ'},
#               'reference': 'ChIJVwPKijpfF2ARsxHtEFgRksQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': '下田ビューホテル, ６３３ Kakisaki, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.67295199999999,
#                                         'lng': 138.973081},
#                            'viewport': {'northeast': {'lat': 34.67429733029151,
#                                                       'lng': 138.9744285302915},
#                                         'southwest': {'lat': 34.67159936970851,
#                                                       'lng': 138.9717305697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Stay with pets Shimoda hot spring inn Harereya',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2700,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113102563083032471871">晴レ屋</a>'],
#                           'photo_reference': 'AeJbb3etKOVl8nrGrRxkZ31BJk2LY0XMo18AT89kJFftbfwZbR5xQyFt3P0A0wL1fxcGuX1LduJUzxvoBOFHt_EK0fYHsgjPmWM3TeNCVIh-f4CgK_aiNqpBKP8RqjVL8cB0yz2K1CQhQKSybW12W_6e8BLTJh4njbNr_aGezsGdLdjWhGDV',
#                           'width': 2061}],
#               'place_id': 'ChIJ-238rCVfF2ARnG5_Ir-RprQ',
#               'plus_code': {'compound_code': 'MXFF+56 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXFF+56'},
#               'rating': 4.8,
#               'reference': 'ChIJ-238rCVfF2ARnG5_Ir-RprQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 47,
#               'vicinity': '804 Kakisaki, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6737486, 'lng': 138.9703858},
#                            'viewport': {'northeast': {'lat': 34.6750687302915,
#                                                       'lng': 138.9717288302915},
#                                         'southwest': {'lat': 34.6723707697085,
#                                                       'lng': 138.9690308697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Minshuku Haji',
#               'photos': [{'height': 1440,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118323505728134877045">Maria '
#                                                 'de la Paz Carucci</a>'],
#                           'photo_reference': 'AeJbb3fYYn_UcP3NxPsbs3T66k_TxrjWkqdox8G7DZLaZD2xHwR-L6nUDk8tPQyek50_QAU0rT0Y1867Zhx6HzByz8wcAtdI1BfYpHyTx_qcGCs-X8pkI-6VPUKsphZQhtIeV_1JWc7koZksyyW13tHXX2Z_dTKLi4-NLyJ2oMcyKcPvumNw',
#                           'width': 2960}],
#               'place_id': 'ChIJKZvM9i9fF2ARypzHMDUvw1Q',
#               'plus_code': {'compound_code': 'MXFC+F5 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXFC+F5'},
#               'rating': 4.4,
#               'reference': 'ChIJKZvM9i9fF2ARypzHMDUvw1Q',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': '708 Kakisaki, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6976509, 'lng': 138.9339413},
#                            'viewport': {'northeast': {'lat': 34.6989203802915,
#                                                       'lng': 138.9352771302915},
#                                         'southwest': {'lat': 34.6962224197085,
#                                                       'lng': 138.9325791697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Kurhaus Ishibashi Ryokan',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103269593151427847184">Emi '
#                                                 'SAWAMOTO</a>'],
#                           'photo_reference': 'AeJbb3e4LYD09K8kMtNm-6b0MFvRstzr6I_UksHQukk0m0Wdxis2sf-dc5reD0mdOoGx8Tz6-lWNi0pgI6qz9fzshSO71gabB5WXqVFqKIpr4JWkt-BCB56wiiZEKflW1-3KQhd4xrWEO--Enoi4jnex5UmUjigNZyvrBOBhP-QqRkLuTJJ-',
#                           'width': 4032}],
#               'place_id': 'ChIJy2yRVm7iGWARsZayHOaYIZw',
#               'plus_code': {'compound_code': 'MWXM+3H Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMWXM+3H'},
#               'rating': 3,
#               'reference': 'ChIJy2yRVm7iGWARsZayHOaYIZw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 94,
#               'vicinity': '185-1 Rendaiji, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.6861402, 'lng': 138.9687343},
#                            'viewport': {'northeast': {'lat': 34.6874536802915,
#                                                       'lng': 138.9700959802915},
#                                         'southwest': {'lat': 34.6847557197085,
#                                                       'lng': 138.9673980197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Ks room Shirahama',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 860,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111413957288864918653">ケーズルーム白浜</a>'],
#                           'photo_reference': 'AeJbb3dRi4yPtiZ6XEE3DAQC3nMTdIrGuNXn8Ls7eeG0gBaeU4zIM5CXP6BeBIjNsJXlvn4x5DsFRdiARkd-b2WbBWmWzuQnkHP3F0S45QVV6EjXRJbXxy4-glj_DziRLpdu4lB2fytyiO0Xk6g4pM2dbQIECXF_nCzGeHhkXIzgbGdFa9AE',
#                           'width': 1077}],
#               'place_id': 'ChIJ78OT5UhfF2ARVPDf-EbbLTI',
#               'plus_code': {'compound_code': 'MXP9+FF Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXP9+FF'},
#               'rating': 4.3,
#               'reference': 'ChIJ78OT5UhfF2ARVPDf-EbbLTI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 24,
#               'vicinity': '2583-2 Shirahama, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.662982, 'lng': 138.932512},
#                            'viewport': {'northeast': {'lat': 34.6642850302915,
#                                                       'lng': 138.9338159802915},
#                                         'southwest': {'lat': 34.6615870697085,
#                                                       'lng': 138.9311180197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Mukai',
#               'photos': [{'height': 2268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103170891549568333459">k '
#                                                 'S</a>'],
#                           'photo_reference': 'AeJbb3eFiu_2mCcs5er8sGMbm4dpZr-7Az-30aCV1p-jKLSmttuG41A2hmuf7jXS5pIpq8T262RvA6dDjtuWwOaiL3HuFof8UdtfWFcIx52Werul1yjPKJexwJ3IH5l6so0fKGJdlTlCTk_d5A_d9X5dR_wnBiKYTJlP9APBW--azQHhdrdN',
#                           'width': 4032}],
#               'place_id': 'ChIJe_uOZO5YF2ARuj_KHcob_2Q',
#               'plus_code': {'compound_code': 'MW7M+52 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMW7M+52'},
#               'rating': 4.8,
#               'reference': 'ChIJe_uOZO5YF2ARuj_KHcob_2Q',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 13,
#               'vicinity': '33 Kisami, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.65786, 'lng': 138.916276},
#                            'viewport': {'northeast': {'lat': 34.6592449302915,
#                                                       'lng': 138.9176440302915},
#                                         'southwest': {'lat': 34.6565469697085,
#                                                       'lng': 138.9149460697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Yazaki',
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102547837696579774082">K '
#                                                 'W</a>'],
#                           'photo_reference': 'AeJbb3cm8fmfkaq8lpIc9415RBiYRbESyG8geLp8Ogc57sKy_OMQrL1_ECAOwyNTP9kFMKx4vZ-GTN-7M6A65u6NhQHRxBVbQoVKmC6EbnOtxb0jMt6BLJNQLhtfVHnxzFSqhYKW6FfUMhiV6CLK8LQmP_8qByt-MAl0MX9HARnFqGNu3LM8',
#                           'width': 3024}],
#               'place_id': 'ChIJCwoVuV5YF2ARySH5X8Qu1h8',
#               'plus_code': {'compound_code': 'MW58+4G Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMW58+4G'},
#               'rating': 3,
#               'reference': 'ChIJCwoVuV5YF2ARySH5X8Qu1h8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 4,
#               'vicinity': '1782 Kisami, Shimoda'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 34.68675, 'lng': 138.972997},
#                            'viewport': {'northeast': {'lat': 34.6881579302915,
#                                                       'lng': 138.9743730802915},
#                                         'southwest': {'lat': 34.6854599697085,
#                                                       'lng': 138.9716751197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Marina Shirahama',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2848,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106599708041114558247">白浜マリーナ</a>'],
#                           'photo_reference': 'AeJbb3fzycTedkR_jeFpNpvCrCNOmulYVwuqe38vYnL0nYhBNbCPFBAI3En0LLkWX9Sp4lNm8UXtXDEH3SWCK4NZxjv6g0XGOeOmdSSChIjRD8zXTIahpQ_T2Gr0DjWZPamteTCmr_fPAiumyrkI1jjrWg-T35iBHG_WGhInilg24kPD9fKM',
#                           'width': 4288}],
#               'place_id': 'ChIJx9ptqUdfF2ARexGa-P6hYdI',
#               'plus_code': {'compound_code': 'MXPF+M5 Shimoda, Shizuoka, Japan',
#                             'global_code': '8Q6WMXPF+M5'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJx9ptqUdfF2ARexGa-P6hYdI',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'lodging',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 59,
#               'vicinity': '2752-16 Shirahama, Shimoda'}],
#  'status': 'OK'}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
        # Get the latitude and longitude.
        lat = row["Lat"]
        lng = row["Lng"]

        # Add the latitude and longitude to location key for the params dictionary.
        params["location"] = f"{lat},{lng}"

        # Use the search term: "lodging" and our latitude and longitude.
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        # Make request and get the JSON data from the search.
        hotels = requests.get(base_url, params=params).json()

            # Grab the first hotel from the results and store the name.
        try:
            hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        except (IndexError):
            print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df[hotel_df["Hotel Name"]== '']
hotel_df
# Out:
#           City Country  Max Temp      Lat       Lng  \
# 0      Shimoda      JP     77.11  34.6667  138.9500
# 2    Jamestown      US     89.94  42.0970  -79.2353
# 9      Kavieng      PG     81.86  -2.5744  150.7967
# 18      Atuona      PF     77.27  -9.8000 -139.0333
# 21    Ajdabiya      LY     86.22  30.7554   20.2263
# ..         ...     ...       ...      ...       ...
# 554       Hami      CN     83.30  42.8000   93.4500
# 560  Tayoltita      MX     84.27  24.0833 -105.9333
# 565     Fuyang      CN     81.86  32.9000  115.8167
# 567     Vanimo      PG     76.66  -2.6741  141.3028
# 574      Anzio      IT     83.98  41.4853   12.6179
#
#                          Hotel Name
# 0               Shimoda Tokyu Hotel
# 2    Hampton Inn & Suites Jamestown
# 9               Nusa Island Retreat
# 18                      Villa Enata
# 21                   Almadina Hotel
# ..                              ...
# 554                Laoyutang Resort
# 560         Hotel La Mina Tayoltita
# 565        Fuyang Wanda Realm Hotel
# 567           Vahmoneh Lodge Vanimo
# 574                Hotel Lido Garda
#
# [193 rows x 6 columns]

# %%
clean_hotel_df = hotel_df[hotel_df["Hotel Name"]!= '']
clean_hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng  \
# 0        Shimoda      JP     77.11  34.6667  138.9500
# 2      Jamestown      US     89.94  42.0970  -79.2353
# 9        Kavieng      PG     81.86  -2.5744  150.7967
# 18        Atuona      PF     77.27  -9.8000 -139.0333
# 21      Ajdabiya      LY     86.22  30.7554   20.2263
# 22  Komsomolskiy      UZ     76.14  40.4272   71.7189
# 33    Le Vauclin      MQ     84.25  14.5452  -60.8388
# 34       Liuzhou      CN     79.97  24.3126  109.3892
# 37       Tautira      PF     76.73 -17.7333 -149.1500
# 38        Maceio      BR     76.44  -9.6658  -35.7353
#
#                         Hotel Name
# 0              Shimoda Tokyu Hotel
# 2   Hampton Inn & Suites Jamestown
# 9              Nusa Island Retreat
# 18                     Villa Enata
# 21                  Almadina Hotel
# 22                       Ikathouse
# 33               Hôtel Cap Macabou
# 34                    Linjiang Inn
# 37                    Pension Oaoa
# 38        Hotel Ponta Verde Maceió

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
